# %% [markdown]
# ## Retrieval Augmented Generation (RAG) with Hugging Face Transformers
#
# #### 1. Retrieval Augmented Generation (RAG):
# Retrieval Augmented Generation (RAG) is a novel approach that combines the strengths of large-scale retrieval systems with the generative capabilities of transformer models like Falcon. In our RAG-based system, when a question is posed, relevant documents or passages are retrieved from a corpus, and then fed alongside the query to the language model. This two-step process enables the model to leverage both external knowledge from the corpus and its internal knowledge to produce more informed and contextually accurate responses.
#
# #### 2. In-context Learning:
# Traditional machine learning models learn from extensive labeled datasets. In contrast, in-context learning pertains to models, especially language models, leveraging a few examples or context provided at inference time to tailor their outputs. Our implementation with Falcon3-1B-Instruct demonstrates this capability through efficient context processing using the Transformers pipeline.
#
# #### 3. LLM Chains/Pipelines:
# LLM chains or pipelines involve stringing together multiple stages or components of a system to achieve a complex task. In our RAG system, the pipeline includes a vector database for efficient retrieval, followed by the Hugging Face Transformers pipeline for response generation. This modular approach allows for easy optimization and updates to individual components.
#
# #### 4. RAG for On-Premise LLM Applications:
# With the growing need for data privacy and proprietary data handling, many enterprises seek solutions to harness the power of LLMs in-house. Our implementation, demonstrates how RAG can be deployed effectively on-premise. By integrating RAG with local data repositories and utilizing hardware acceleration, enterprises can build powerful LLM applications tailored to their specific needs while ensuring data confidentiality.
#
# #### 5. RAG vs Fine-Tuning:
# While RAG is a powerful approach on its own, it can also be combined with different model architectures to enhance LLM capabilities. Our implementation focuses on using RAG with the Falcon3-1B-Instruct model, demonstrating how external knowledge retrieval can complement the model's built-in capabilities. This approach allows for dynamic knowledge integration without the need for continuous model retraining.

# %% [markdown]
# ### Getting Started
# 1. Run the installation cell (first time only)
# 2. Execute all cells in order
# 3. The interactive interface will appear in the final cell
# 4. Select your preferences and start chatting!

# %% [markdown]
# ### Install dependencies. Only run the first time.

# %%
# %pip install langchain accelerate transformers datasets tiktoken chromadb sentence_transformers langchain-community ipywidgets pandas --no-warn-script-location
# Out:
# Requirement already satisfied: langchain in /opt/miniconda3/envs/genai-labs/lib/python3.12/site-packages (1.2.14)
# Requirement already satisfied: accelerate in /opt/miniconda3/envs/genai-labs/lib/python3.12/site-packages (1.12.0)
# Requirement already satisfied: transformers in /opt/miniconda3/envs/genai-labs/lib/python3.12/site-packages (4.57.3)
# Requirement already satisfied: datasets in /opt/miniconda3/envs/genai-labs/lib/python3.12/site-packages (4.4.2)
# Requirement already satisfied: tiktoken in /opt/miniconda3/envs/genai-labs/lib/python3.12/site-packages (0.12.0)
# Requirement already satisfied: chromadb in /opt/miniconda3/envs/genai-labs/lib/python3.12/site-packages (1.5.5)
# Requirement already satisfied: sentence_transformers in /opt/miniconda3/envs/genai-labs/lib/python3.12/site-packages (5.3.0)
# Requirement already satisfied: langchain-community in /opt/miniconda3/envs/genai-labs/lib/python3.12/site-packages (0.4.1)
# Requirement already satisfied: ipywidgets in /opt/miniconda3/envs/genai-labs/lib/python3.12/site-packages (8.1.8)
# Requirement already satisfied: pandas in /opt/miniconda3/envs/genai-labs/lib/python3.12/site-packages (2.3.3)
# Requirement already satisfied: langchain-core<2.0.0,>=1.2.10 in /opt/miniconda3/envs/genai-labs/lib/python3.12/site-packages (from langchain) (1.2.23)
# Requirement already satisfied: langgraph<1.2.0,>=1.1.1 in /opt/miniconda3/envs/genai-labs/lib/python3.12/site-packages (from langchain) (1.1.4)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in /opt/miniconda3/envs/genai-labs/lib/python3.12/site-packages (from langchain) (2.12.5)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in /opt/miniconda3/envs/genai-labs/lib/python3.12/site-packages (from langchain-core<2.0.0,>=1.2.10->langchain) (1.33)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in /opt/miniconda3/envs/genai-labs/lib/python3.12/site-packages (from langchain-core<2.0.0,>=1.2.10->langchain) (0.7.23)
# Requirement already satisfied: packaging>=23.2.0 in /opt/miniconda3/envs/genai-labs/lib/python3.12/site-packages (from langchain-core<2.0.0,>=1.2.10->langchain) (25.0)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in /opt/miniconda3/envs/genai-labs/lib/python3.12/site-packages (from langchain-core<2.0.0,>=1.2.10->langchain) (6.0.3)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in /opt/miniconda3/envs/genai-labs/lib/python3.12/site-packages (from langchain-core<2.0.0,>=1.2.10->langchain) (9.1.4)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in /opt/miniconda3/envs/genai-labs/lib/python3.12/site-packages (from langchain-core<2.0.0,>=1.2.10->langchain) (4.15.0)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in /opt/miniconda3/envs/genai-labs/lib/python3.12/site-packages (from langchain-core<2.0.0,>=1.2.10->langchain) (0.14.1)
# Requirement already satisfied: jsonpointer>=1.9 in /opt/miniconda3/envs/genai-labs/lib/python3.12/site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.2.10->langchain) (3.0.0)
# Requirement already satisfied: langgraph-checkpoint<5.0.0,>=2.1.0 in /opt/miniconda3/envs/genai-labs/lib/python3.12/site-packages (from langgraph<1.2.0,>=1.1.1->langchain) (4.0.1)
# Requirement already satisfied: langgraph-prebuilt<1.1.0,>=1.0.8 in /opt/miniconda3/envs/genai-labs/lib/python3.12/site-packages (from langgraph<1.2.0,>=1.1.1->langchain) (1.0.8)
# Requirement already satisfied: langgraph-sdk<0.4.0,>=0.3.0 in /opt/miniconda3/envs/genai-labs/lib/python3.12/site-packages (from langgraph<1.2.0,>=1.1.1->langchain) (0.3.12)
# Requirement already satisfied: xxhash>=3.5.0 in /opt/miniconda3/envs/genai-labs/lib/python3.12/site-packages (from langgraph<1.2.0,>=1.1.1->langchain) (3.6.0)
# Requirement already satisfied: ormsgpack>=1.12.0 in /opt/miniconda3/envs/genai-labs/lib/python3.12/site-packages (from langgraph-checkpoint<5.0.0,>=2.1.0->langgraph<1.2.0,>=1.1.1->langchain) (1.12.2)
# Requirement already satisfied: httpx>=0.25.2 in /opt/miniconda3/envs/genai-labs/lib/python3.12/site-packages (from langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.2.0,>=1.1.1->langchain) (0.28.1)
# Requirement already satisfied: orjson>=3.11.5 in /opt/miniconda3/envs/genai-labs/lib/python3.12/site-packages (from langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.2.0,>=1.1.1->langchain) (3.11.8)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in /opt/miniconda3/envs/genai-labs/lib/python3.12/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.10->langchain) (1.0.0)
# Requirement already satisfied: requests>=2.0.0 in /opt/miniconda3/envs/genai-labs/lib/python3.12/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.10->langchain) (2.32.5)
# Requirement already satisfied: zstandard>=0.23.0 in /opt/miniconda3/envs/genai-labs/lib/python3.12/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.10->langchain) (0.25.0)
# Requirement already satisfied: anyio in /opt/miniconda3/envs/genai-labs/lib/python3.12/site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.2.0,>=1.1.1->langchain) (4.12.1)
# Requirement already satisfied: certifi in /opt/miniconda3/envs/genai-labs/lib/python3.12/site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.2.0,>=1.1.1->langchain) (2026.1.4)
# Requirement already satisfied: httpcore==1.* in /opt/miniconda3/envs/genai-labs/lib/python3.12/site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.2.0,>=1.1.1->langchain) (1.0.9)
# Requirement already satisfied: idna in /opt/miniconda3/envs/genai-labs/lib/python3.12/site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.2.0,>=1.1.1->langchain) (3.11)
# Requirement already satisfied: h11>=0.16 in /opt/miniconda3/envs/genai-labs/lib/python3.12/site-packages (from httpcore==1.*->httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.2.0,>=1.1.1->langchain) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /opt/miniconda3/envs/genai-labs/lib/python3.12/site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in /opt/miniconda3/envs/genai-labs/lib/python3.12/site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in /opt/miniconda3/envs/genai-labs/lib/python3.12/site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.4.2)
# Requirement already satisfied: numpy>=1.17 in /opt/miniconda3/envs/genai-labs/lib/python3.12/site-packages (from accelerate) (2.4.1)
# Requirement already satisfied: psutil in /opt/miniconda3/envs/genai-labs/lib/python3.12/site-packages (from accelerate) (7.2.1)
# Requirement already satisfied: torch>=2.0.0 in /opt/miniconda3/envs/genai-labs/lib/python3.12/site-packages (from accelerate) (2.9.1)
# Requirement already satisfied: huggingface_hub>=0.21.0 in /opt/miniconda3/envs/genai-labs/lib/python3.12/site-packages (from accelerate) (0.36.0)
# Requirement already satisfied: safetensors>=0.4.3 in /opt/miniconda3/envs/genai-labs/lib/python3.12/site-packages (from accelerate) (0.7.0)
# Requirement already satisfied: filelock in /opt/miniconda3/envs/genai-labs/lib/python3.12/site-packages (from transformers) (3.20.3)
# Requirement already satisfied: regex!=2019.12.17 in /opt/miniconda3/envs/genai-labs/lib/python3.12/site-packages (from transformers) (2025.11.3)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in /opt/miniconda3/envs/genai-labs/lib/python3.12/site-packages (from transformers) (0.22.2)
# Requirement already satisfied: tqdm>=4.27 in /opt/miniconda3/envs/genai-labs/lib/python3.12/site-packages (from transformers) (4.67.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /opt/miniconda3/envs/genai-labs/lib/python3.12/site-packages (from huggingface_hub>=0.21.0->accelerate) (2025.10.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /opt/miniconda3/envs/genai-labs/lib/python3.12/site-packages (from huggingface_hub>=0.21.0->accelerate) (1.2.0)
# Requirement already satisfied: pyarrow>=21.0.0 in /opt/miniconda3/envs/genai-labs/lib/python3.12/site-packages (from datasets) (22.0.0)
# Requirement already satisfied: dill<0.4.1,>=0.3.0 in /opt/miniconda3/envs/genai-labs/lib/python3.12/site-packages (from datasets) (0.4.0)
# Requirement already satisfied: multiprocess<0.70.19 in /opt/miniconda3/envs/genai-labs/lib/python3.12/site-packages (from datasets) (0.70.18)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /opt/miniconda3/envs/genai-labs/lib/python3.12/site-packages (from fsspec[http]<=2025.10.0,>=2023.1.0->datasets) (3.13.3)
# Requirement already satisfied: build>=1.0.3 in /opt/miniconda3/envs/genai-labs/lib/python3.12/site-packages (from chromadb) (1.4.2)
# Requirement already satisfied: pydantic-settings>=2.0 in /opt/miniconda3/envs/genai-labs/lib/python3.12/site-packages (from chromadb) (2.13.1)
# Requirement already satisfied: pybase64>=1.4.1 in /opt/miniconda3/envs/genai-labs/lib/python3.12/site-packages (from chromadb) (1.4.3)
# Requirement already satisfied: uvicorn>=0.18.3 in /opt/miniconda3/envs/genai-labs/lib/python3.12/site-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.42.0)
# Requirement already satisfied: onnxruntime>=1.14.1 in /opt/miniconda3/envs/genai-labs/lib/python3.12/site-packages (from chromadb) (1.24.4)
# Requirement already satisfied: opentelemetry-api>=1.2.0 in /opt/miniconda3/envs/genai-labs/lib/python3.12/site-packages (from chromadb) (1.40.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-grpc>=1.2.0 in /opt/miniconda3/envs/genai-labs/lib/python3.12/site-packages (from chromadb) (1.40.0)
# Requirement already satisfied: opentelemetry-sdk>=1.2.0 in /opt/miniconda3/envs/genai-labs/lib/python3.12/site-packages (from chromadb) (1.40.0)
# Requirement already satisfied: pypika>=0.48.9 in /opt/miniconda3/envs/genai-labs/lib/python3.12/site-packages (from chromadb) (0.51.1)
# Requirement already satisfied: overrides>=7.3.1 in /opt/miniconda3/envs/genai-labs/lib/python3.12/site-packages (from chromadb) (7.7.0)
# Requirement already satisfied: importlib-resources in /opt/miniconda3/envs/genai-labs/lib/python3.12/site-packages (from chromadb) (6.5.2)
# Requirement already satisfied: grpcio>=1.58.0 in /opt/miniconda3/envs/genai-labs/lib/python3.12/site-packages (from chromadb) (1.80.0)
# Requirement already satisfied: bcrypt>=4.0.1 in /opt/miniconda3/envs/genai-labs/lib/python3.12/site-packages (from chromadb) (5.0.0)
# Requirement already satisfied: typer>=0.9.0 in /opt/miniconda3/envs/genai-labs/lib/python3.12/site-packages (from chromadb) (0.24.1)
# Requirement already satisfied: kubernetes>=28.1.0 in /opt/miniconda3/envs/genai-labs/lib/python3.12/site-packages (from chromadb) (35.0.0)
# Requirement already satisfied: mmh3>=4.0.1 in /opt/miniconda3/envs/genai-labs/lib/python3.12/site-packages (from chromadb) (5.2.1)
# Requirement already satisfied: rich>=10.11.0 in /opt/miniconda3/envs/genai-labs/lib/python3.12/site-packages (from chromadb) (14.3.3)
# Requirement already satisfied: jsonschema>=4.19.0 in /opt/miniconda3/envs/genai-labs/lib/python3.12/site-packages (from chromadb) (4.26.0)
# Requirement already satisfied: scikit-learn in /opt/miniconda3/envs/genai-labs/lib/python3.12/site-packages (from sentence_transformers) (1.8.0)
# Requirement already satisfied: scipy in /opt/miniconda3/envs/genai-labs/lib/python3.12/site-packages (from sentence_transformers) (1.17.1)
# Requirement already satisfied: langchain-classic<2.0.0,>=1.0.0 in /opt/miniconda3/envs/genai-labs/lib/python3.12/site-packages (from langchain-community) (1.0.3)
# Requirement already satisfied: SQLAlchemy<3.0.0,>=1.4.0 in /opt/miniconda3/envs/genai-labs/lib/python3.12/site-packages (from langchain-community) (2.0.48)
# Requirement already satisfied: dataclasses-json<0.7.0,>=0.6.7 in /opt/miniconda3/envs/genai-labs/lib/python3.12/site-packages (from langchain-community) (0.6.7)
# Requirement already satisfied: httpx-sse<1.0.0,>=0.4.0 in /opt/miniconda3/envs/genai-labs/lib/python3.12/site-packages (from langchain-community) (0.4.3)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /opt/miniconda3/envs/genai-labs/lib/python3.12/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.10.0,>=2023.1.0->datasets) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /opt/miniconda3/envs/genai-labs/lib/python3.12/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.10.0,>=2023.1.0->datasets) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /opt/miniconda3/envs/genai-labs/lib/python3.12/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.10.0,>=2023.1.0->datasets) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /opt/miniconda3/envs/genai-labs/lib/python3.12/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.10.0,>=2023.1.0->datasets) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /opt/miniconda3/envs/genai-labs/lib/python3.12/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.10.0,>=2023.1.0->datasets) (6.7.0)
# Requirement already satisfied: propcache>=0.2.0 in /opt/miniconda3/envs/genai-labs/lib/python3.12/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.10.0,>=2023.1.0->datasets) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /opt/miniconda3/envs/genai-labs/lib/python3.12/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.10.0,>=2023.1.0->datasets) (1.22.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in /opt/miniconda3/envs/genai-labs/lib/python3.12/site-packages (from dataclasses-json<0.7.0,>=0.6.7->langchain-community) (3.26.2)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in /opt/miniconda3/envs/genai-labs/lib/python3.12/site-packages (from dataclasses-json<0.7.0,>=0.6.7->langchain-community) (0.9.0)
# Requirement already satisfied: langchain-text-splitters<2.0.0,>=1.1.1 in /opt/miniconda3/envs/genai-labs/lib/python3.12/site-packages (from langchain-classic<2.0.0,>=1.0.0->langchain-community) (1.1.1)
# Requirement already satisfied: python-dotenv>=0.21.0 in /opt/miniconda3/envs/genai-labs/lib/python3.12/site-packages (from pydantic-settings>=2.0->chromadb) (1.2.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /opt/miniconda3/envs/genai-labs/lib/python3.12/site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.10->langchain) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/miniconda3/envs/genai-labs/lib/python3.12/site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.10->langchain) (2.6.3)
# Requirement already satisfied: greenlet>=1 in /opt/miniconda3/envs/genai-labs/lib/python3.12/site-packages (from SQLAlchemy<3.0.0,>=1.4.0->langchain-community) (3.3.2)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /opt/miniconda3/envs/genai-labs/lib/python3.12/site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7.0,>=0.6.7->langchain-community) (1.1.0)
# Requirement already satisfied: comm>=0.1.3 in /opt/miniconda3/envs/genai-labs/lib/python3.12/site-packages (from ipywidgets) (0.2.3)
# Requirement already satisfied: ipython>=6.1.0 in /opt/miniconda3/envs/genai-labs/lib/python3.12/site-packages (from ipywidgets) (9.9.0)
# Requirement already satisfied: traitlets>=4.3.1 in /opt/miniconda3/envs/genai-labs/lib/python3.12/site-packages (from ipywidgets) (5.14.3)
# Requirement already satisfied: widgetsnbextension~=4.0.14 in /opt/miniconda3/envs/genai-labs/lib/python3.12/site-packages (from ipywidgets) (4.0.15)
# Requirement already satisfied: jupyterlab_widgets~=3.0.15 in /opt/miniconda3/envs/genai-labs/lib/python3.12/site-packages (from ipywidgets) (3.0.16)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/miniconda3/envs/genai-labs/lib/python3.12/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /opt/miniconda3/envs/genai-labs/lib/python3.12/site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /opt/miniconda3/envs/genai-labs/lib/python3.12/site-packages (from pandas) (2025.3)
# Requirement already satisfied: pyproject_hooks in /opt/miniconda3/envs/genai-labs/lib/python3.12/site-packages (from build>=1.0.3->chromadb) (1.2.0)
# Requirement already satisfied: decorator>=4.3.2 in /opt/miniconda3/envs/genai-labs/lib/python3.12/site-packages (from ipython>=6.1.0->ipywidgets) (5.2.1)
# Requirement already satisfied: ipython-pygments-lexers>=1.0.0 in /opt/miniconda3/envs/genai-labs/lib/python3.12/site-packages (from ipython>=6.1.0->ipywidgets) (1.1.1)
# Requirement already satisfied: jedi>=0.18.1 in /opt/miniconda3/envs/genai-labs/lib/python3.12/site-packages (from ipython>=6.1.0->ipywidgets) (0.19.2)
# Requirement already satisfied: matplotlib-inline>=0.1.5 in /opt/miniconda3/envs/genai-labs/lib/python3.12/site-packages (from ipython>=6.1.0->ipywidgets) (0.2.1)
# Requirement already satisfied: pexpect>4.3 in /opt/miniconda3/envs/genai-labs/lib/python3.12/site-packages (from ipython>=6.1.0->ipywidgets) (4.9.0)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in /opt/miniconda3/envs/genai-labs/lib/python3.12/site-packages (from ipython>=6.1.0->ipywidgets) (3.0.52)
# Requirement already satisfied: pygments>=2.11.0 in /opt/miniconda3/envs/genai-labs/lib/python3.12/site-packages (from ipython>=6.1.0->ipywidgets) (2.19.2)
# Requirement already satisfied: stack_data>=0.6.0 in /opt/miniconda3/envs/genai-labs/lib/python3.12/site-packages (from ipython>=6.1.0->ipywidgets) (0.6.3)
# Requirement already satisfied: wcwidth in /opt/miniconda3/envs/genai-labs/lib/python3.12/site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython>=6.1.0->ipywidgets) (0.2.14)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /opt/miniconda3/envs/genai-labs/lib/python3.12/site-packages (from jedi>=0.18.1->ipython>=6.1.0->ipywidgets) (0.8.5)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /opt/miniconda3/envs/genai-labs/lib/python3.12/site-packages (from jsonschema>=4.19.0->chromadb) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in /opt/miniconda3/envs/genai-labs/lib/python3.12/site-packages (from jsonschema>=4.19.0->chromadb) (0.37.0)
# Requirement already satisfied: rpds-py>=0.25.0 in /opt/miniconda3/envs/genai-labs/lib/python3.12/site-packages (from jsonschema>=4.19.0->chromadb) (0.30.0)
# Requirement already satisfied: six>=1.9.0 in /opt/miniconda3/envs/genai-labs/lib/python3.12/site-packages (from kubernetes>=28.1.0->chromadb) (1.17.0)
# Requirement already satisfied: websocket-client!=0.40.0,!=0.41.*,!=0.42.*,>=0.32.0 in /opt/miniconda3/envs/genai-labs/lib/python3.12/site-packages (from kubernetes>=28.1.0->chromadb) (1.9.0)
# Requirement already satisfied: requests-oauthlib in /opt/miniconda3/envs/genai-labs/lib/python3.12/site-packages (from kubernetes>=28.1.0->chromadb) (2.0.0)
# Requirement already satisfied: durationpy>=0.7 in /opt/miniconda3/envs/genai-labs/lib/python3.12/site-packages (from kubernetes>=28.1.0->chromadb) (0.10)
# Requirement already satisfied: flatbuffers in /opt/miniconda3/envs/genai-labs/lib/python3.12/site-packages (from onnxruntime>=1.14.1->chromadb) (25.12.19)
# Requirement already satisfied: protobuf in /opt/miniconda3/envs/genai-labs/lib/python3.12/site-packages (from onnxruntime>=1.14.1->chromadb) (6.33.6)
# Requirement already satisfied: sympy in /opt/miniconda3/envs/genai-labs/lib/python3.12/site-packages (from onnxruntime>=1.14.1->chromadb) (1.14.0)
# Requirement already satisfied: importlib-metadata<8.8.0,>=6.0 in /opt/miniconda3/envs/genai-labs/lib/python3.12/site-packages (from opentelemetry-api>=1.2.0->chromadb) (8.7.1)
# Requirement already satisfied: zipp>=3.20 in /opt/miniconda3/envs/genai-labs/lib/python3.12/site-packages (from importlib-metadata<8.8.0,>=6.0->opentelemetry-api>=1.2.0->chromadb) (3.23.0)
# Requirement already satisfied: googleapis-common-protos~=1.57 in /opt/miniconda3/envs/genai-labs/lib/python3.12/site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.73.1)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-common==1.40.0 in /opt/miniconda3/envs/genai-labs/lib/python3.12/site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.40.0)
# Requirement already satisfied: opentelemetry-proto==1.40.0 in /opt/miniconda3/envs/genai-labs/lib/python3.12/site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.40.0)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.61b0 in /opt/miniconda3/envs/genai-labs/lib/python3.12/site-packages (from opentelemetry-sdk>=1.2.0->chromadb) (0.61b0)
# Requirement already satisfied: ptyprocess>=0.5 in /opt/miniconda3/envs/genai-labs/lib/python3.12/site-packages (from pexpect>4.3->ipython>=6.1.0->ipywidgets) (0.7.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /opt/miniconda3/envs/genai-labs/lib/python3.12/site-packages (from rich>=10.11.0->chromadb) (4.0.0)
# Requirement already satisfied: mdurl~=0.1 in /opt/miniconda3/envs/genai-labs/lib/python3.12/site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->chromadb) (0.1.2)
# Requirement already satisfied: executing>=1.2.0 in /opt/miniconda3/envs/genai-labs/lib/python3.12/site-packages (from stack_data>=0.6.0->ipython>=6.1.0->ipywidgets) (2.2.1)
# Requirement already satisfied: asttokens>=2.1.0 in /opt/miniconda3/envs/genai-labs/lib/python3.12/site-packages (from stack_data>=0.6.0->ipython>=6.1.0->ipywidgets) (3.0.1)
# Requirement already satisfied: pure-eval in /opt/miniconda3/envs/genai-labs/lib/python3.12/site-packages (from stack_data>=0.6.0->ipython>=6.1.0->ipywidgets) (0.2.3)
# Requirement already satisfied: setuptools in /opt/miniconda3/envs/genai-labs/lib/python3.12/site-packages (from torch>=2.0.0->accelerate) (80.9.0)
# Requirement already satisfied: networkx>=2.5.1 in /opt/miniconda3/envs/genai-labs/lib/python3.12/site-packages (from torch>=2.0.0->accelerate) (3.6.1)
# Requirement already satisfied: jinja2 in /opt/miniconda3/envs/genai-labs/lib/python3.12/site-packages (from torch>=2.0.0->accelerate) (3.1.6)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.8.93 in /opt/miniconda3/envs/genai-labs/lib/python3.12/site-packages (from torch>=2.0.0->accelerate) (12.8.93)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.8.90 in /opt/miniconda3/envs/genai-labs/lib/python3.12/site-packages (from torch>=2.0.0->accelerate) (12.8.90)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.8.90 in /opt/miniconda3/envs/genai-labs/lib/python3.12/site-packages (from torch>=2.0.0->accelerate) (12.8.90)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /opt/miniconda3/envs/genai-labs/lib/python3.12/site-packages (from torch>=2.0.0->accelerate) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.8.4.1 in /opt/miniconda3/envs/genai-labs/lib/python3.12/site-packages (from torch>=2.0.0->accelerate) (12.8.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.3.83 in /opt/miniconda3/envs/genai-labs/lib/python3.12/site-packages (from torch>=2.0.0->accelerate) (11.3.3.83)
# Requirement already satisfied: nvidia-curand-cu12==10.3.9.90 in /opt/miniconda3/envs/genai-labs/lib/python3.12/site-packages (from torch>=2.0.0->accelerate) (10.3.9.90)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.3.90 in /opt/miniconda3/envs/genai-labs/lib/python3.12/site-packages (from torch>=2.0.0->accelerate) (11.7.3.90)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.8.93 in /opt/miniconda3/envs/genai-labs/lib/python3.12/site-packages (from torch>=2.0.0->accelerate) (12.5.8.93)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /opt/miniconda3/envs/genai-labs/lib/python3.12/site-packages (from torch>=2.0.0->accelerate) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.5 in /opt/miniconda3/envs/genai-labs/lib/python3.12/site-packages (from torch>=2.0.0->accelerate) (2.27.5)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.3.20 in /opt/miniconda3/envs/genai-labs/lib/python3.12/site-packages (from torch>=2.0.0->accelerate) (3.3.20)
# Requirement already satisfied: nvidia-nvtx-cu12==12.8.90 in /opt/miniconda3/envs/genai-labs/lib/python3.12/site-packages (from torch>=2.0.0->accelerate) (12.8.90)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.8.93 in /opt/miniconda3/envs/genai-labs/lib/python3.12/site-packages (from torch>=2.0.0->accelerate) (12.8.93)
# Requirement already satisfied: nvidia-cufile-cu12==1.13.1.3 in /opt/miniconda3/envs/genai-labs/lib/python3.12/site-packages (from torch>=2.0.0->accelerate) (1.13.1.3)
# Requirement already satisfied: triton==3.5.1 in /opt/miniconda3/envs/genai-labs/lib/python3.12/site-packages (from torch>=2.0.0->accelerate) (3.5.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /opt/miniconda3/envs/genai-labs/lib/python3.12/site-packages (from sympy->onnxruntime>=1.14.1->chromadb) (1.3.0)
# Requirement already satisfied: click>=8.2.1 in /opt/miniconda3/envs/genai-labs/lib/python3.12/site-packages (from typer>=0.9.0->chromadb) (8.3.1)
# Requirement already satisfied: shellingham>=1.3.0 in /opt/miniconda3/envs/genai-labs/lib/python3.12/site-packages (from typer>=0.9.0->chromadb) (1.5.4)
# Requirement already satisfied: annotated-doc>=0.0.2 in /opt/miniconda3/envs/genai-labs/lib/python3.12/site-packages (from typer>=0.9.0->chromadb) (0.0.4)
# Requirement already satisfied: httptools>=0.6.3 in /opt/miniconda3/envs/genai-labs/lib/python3.12/site-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.7.1)
# Requirement already satisfied: uvloop>=0.15.1 in /opt/miniconda3/envs/genai-labs/lib/python3.12/site-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.22.1)
# Requirement already satisfied: watchfiles>=0.20 in /opt/miniconda3/envs/genai-labs/lib/python3.12/site-packages (from uvicorn[standard]>=0.18.3->chromadb) (1.1.1)
# Requirement already satisfied: websockets>=10.4 in /opt/miniconda3/envs/genai-labs/lib/python3.12/site-packages (from uvicorn[standard]>=0.18.3->chromadb) (16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/miniconda3/envs/genai-labs/lib/python3.12/site-packages (from jinja2->torch>=2.0.0->accelerate) (3.0.3)
# Requirement already satisfied: oauthlib>=3.0.0 in /opt/miniconda3/envs/genai-labs/lib/python3.12/site-packages (from requests-oauthlib->kubernetes>=28.1.0->chromadb) (3.3.1)
# Requirement already satisfied: joblib>=1.3.0 in /opt/miniconda3/envs/genai-labs/lib/python3.12/site-packages (from scikit-learn->sentence_transformers) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.2.0 in /opt/miniconda3/envs/genai-labs/lib/python3.12/site-packages (from scikit-learn->sentence_transformers) (3.6.0)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# The code below builds RAGBot. RAGBot class is a streamlined implementation of a Retrieval-Augmented Generation (RAG) chatbot, designed to integrate large language models for generating contextually relevant responses. At its core, it manages the downloading and initialization of HuggingFace Transformer models, such as the "Falcon3-1B-Instruct" model, with support for handling large model files. The system leverages hardware acceleration for efficient model inference. It automates the process of fetching and structuring dialogue datasets from predefined sources. The chatbot utilizes the HuggingFace Transformers library, allowing for efficient model inference with adjustable parameters like the number of threads and maximum tokens. A key feature of RAGBot is its ability to build a vector database for text retrieval, significantly bolstering its ability to pull relevant document snippets based on user queries. This functionality, combined with a retrieval mechanism and an inference method using the Transformers pipeline, makes RAGBot a simple tool for developers aiming to learn about RAG and leverage this implementation as a basis for their implementation.

# %% [markdown]
# ## Package Imports
#
# Core libraries for RAG implementation including Hugging FaceTransformers, LangChain components, and utilities for UI and data handling

# %%
import sys
import os
import requests
import contextlib
import pandas as pd
import time
import io
import ipywidgets as widgets
from IPython.display import display, HTML

from tqdm import tqdm
from transformers import AutoTokenizer, AutoModelForCausalLM
from langchain_classic.chains import LLMChain
from langchain_classic.prompts import PromptTemplate
from langchain_classic.document_loaders import TextLoader
from langchain_classic.text_splitter import RecursiveCharacterTextSplitter
from langchain_classic.indexes import VectorstoreIndexCreator
from langchain_classic.embeddings import HuggingFaceEmbeddings
from datasets import load_dataset

# %% [markdown]
# ### RAGBot Class Implementation
#
# The RAGBot class implements a Retrieval-Augmented Generation system. Key components include:
#
# #### Core Features
# - Model Management: Handles initialization of Hugging Face Transformer models (currently supporting Falcon3-1B-Instruct)
# - Dataset Handling: Manages dialogue datasets from various domains (robot maintenance, sports coaching, academia, retail)
# - Vector Database: Creates and manages embeddings for efficient text retrieval
# - RAG Pipeline: Combines context retrieval with language model inference
#
# #### Key Methods
# - `get_model()`: Initializes the specified language model
# - `download_dataset()`: Fetches and processes dialogue datasets
# - `load_model()`: Configures the transformer model with specified parameters
# - `build_vectordb()`: Creates a searchable vector database from text data
# - `retrieval_mechanism()`: Implements context retrieval based on user queries
# - `inference()`: Generates responses using the loaded model and retrieved context
#
# The implementation leverages Hugging Face Transformers for model operations and LangChain for RAG functionality, providing a streamlined approach to context-aware response generation.

# %%
class RAGBot:
    """
    A class to handle model downloading, dataset management, model loading, vector database
    creation, retrieval mechanisms, and inference for a response generation bot.
    """
    def __init__(self):
        self.model_name = ""
        self.data_path = ""
        self.user_input = ""
        self.model = ""
        self.max_tokens = 50
        self.top_k = 50
        self.available_models = {
            "Falcon": "tiiuae/Falcon3-1B-Instruct",
            "Gemma-2-2B-IT": "google/gemma-2-2b-it",
        }

    def get_model(self, model, chunk_size: int = 10000):
        self.model = model
        if model in self.available_models:
            self.model_name = self.available_models[model]
        else:
            print(f"Unknown model '{model}', defaulting to Falcon.")
            self.model_name = self.available_models["Falcon"]

    def download_dataset(self, dataset):
        self.data_path = dataset + '_dialogues.txt'
        if not os.path.isfile(self.data_path):
            datasets = {
                "robot maintenance": "FunDialogues/customer-service-robot-support", 
                "basketball coach": "FunDialogues/sports-basketball-coach", 
                "physics professor": "FunDialogues/academia-physics-office-hours",
                "grocery cashier" : "FunDialogues/customer-service-grocery-cashier"
            }
            dataset = load_dataset(f"{datasets[dataset]}")
            dialogues = dataset['train']
            df = pd.DataFrame(dialogues, columns=['id', 'description', 'dialogue'])
            dialog_df = df['dialogue']
            dialog_df.to_csv(self.data_path, sep=' ', index=False)
        else:
            print('data already exists in path.')

    def load_model(self, n_threads, max_tokens, repeat_penalty, n_batch, top_k):
        self.tokenizer = AutoTokenizer.from_pretrained(self.model_name)
        self.llm = AutoModelForCausalLM.from_pretrained(
            self.model_name,
            dtype="auto",
            device_map="auto"
        )
        self.tokenizer.pad_token = self.tokenizer.eos_token
        self.llm.config.pad_token_id = self.llm.config.eos_token_id
        self.max_tokens = max_tokens
        self.top_k = top_k

    def build_vectordb(self, chunk_size, overlap):
        loader = TextLoader(self.data_path)
        text_splitter = RecursiveCharacterTextSplitter(chunk_size=chunk_size, chunk_overlap=overlap)
        self.index = VectorstoreIndexCreator(
            embedding=HuggingFaceEmbeddings(), 
            text_splitter=text_splitter
        ).from_loaders([loader])

    def retrieval_mechanism(self, user_input, top_k=1, context_verbosity=False, rag_off=False):
        self.user_input = user_input
        self.context_verbosity = context_verbosity
        results = self.index.vectorstore.similarity_search(self.user_input, k=top_k)
        context = "\n".join([document.page_content for document in results])
        if self.context_verbosity:
            print(f"Retrieving information related to your question...")
            print(f"Found this content which is most similar to your question: {context}")
        if rag_off:
            self.full_prompt = f"Question: {user_input}\nAnswer:"
        else:
            self.full_prompt = f"""Context: {context}\n\nQuestion: {user_input}\nAnswer:"""

    def inference(self):
        if self.context_verbosity:
            print(f"Your Query: {self.full_prompt}")

        messages = [
            {"role": "system", "content": "You are a helpful assistant. Use the provided context to answer questions accurately."},
            {"role": "user", "content": self.full_prompt}
        ]
        text = self.tokenizer.apply_chat_template(
            messages,
            tokenize=False,
            add_generation_prompt=True
        )
        model_inputs = self.tokenizer([text], return_tensors="pt").to(self.llm.device)
        generated_ids = self.llm.generate(
            **model_inputs,
            max_new_tokens=self.max_tokens,
            do_sample=True,
            top_k=self.top_k,
            temperature=0.7
        )
        generated_ids = [
            output_ids[len(input_ids):] for input_ids, output_ids in zip(model_inputs.input_ids, generated_ids)
        ]
        response = self.tokenizer.batch_decode(generated_ids, skip_special_tokens=True)[0]
        return response

# %% [markdown]
# ### Customizing Your RAG LLM Chatbot Experience
#
# Welcome to the RAG LLM Chatbot interface! This guide will help you understand how to use the various widgets to customize your chatbot experience.
#
# #### Interface Elements
#
# ##### Model Selection
# - **Model Dropdown**: Choose the model for your chatbot.
#   - Currently using the Falcon3-1B-Instruct model from TII.
#   - More models will be added in future updates.
#
# ##### Query Input
# - **Query Text Box**: Enter your query here.
#   - Type the question or statement you want the chatbot to respond to.
#   - The text area provides ample space for longer queries.
#
# ##### Response Customization
# - **Top K Slider**: Adjust the number of top results to consider for generating responses.
#   - Slide to increase or decrease the value. The range is from 1 to 4.
#   - This adjusts how many similar context passages are retrieved for answering.
#
# - **RAG OFF Checkbox**: Toggle whether to use Retrieval-Augmented Generation (RAG) or not.
#   - Check this box if you want to turn off RAG and use only the base model for responses.
#   - Useful for comparing RAG-enhanced vs. basic model responses.
#
# ##### Data Processing Settings
# - **Chunk Size Input**: Set the size of text chunks for processing.
#   - Enter a value to determine how large each text chunk should be (5-5000).
#   - This affects how the context documents are segmented for retrieval.
#
# - **Overlap Input**: Define the overlap size between chunks.
#   - Set a value for how much overlap there should be between text chunks (0-1000).
#   - Higher overlap can help maintain context continuity between chunks.
#
# ##### Dataset and Performance
# - **Dataset Dropdown**: Choose the dataset for context retrieval.
#   - Options include: 'robot maintenance', 'basketball coach', 'physics professor', 'grocery cashier'.
#   - Each dataset provides different domain-specific knowledge.
#
# - **Threads Slider**: Select the number of threads for processing.
#   - Adjust the slider to set the number of threads (2-200).
#   - Higher values may improve performance on multi-core systems.
#
# - **Max Tokens Input**: Specify the maximum length of generated responses.
#   - Enter a value to set the token limit (5-500).
#   - Higher values allow for longer, more detailed responses.
#
# ##### Submit Button
# - **Submit**: Click this button to process your query and generate a response.
#   - The response will appear in a styled blue box below the interface.
#
# ### How to Use
# 1. Select your desired model from the **Model Dropdown**.
# 2. Type your query in the **Query Text Box**.
# 3. Set the **Top K Slider** for context retrieval amount.
# 4. Configure **Chunk Size** and **Overlap** for text processing.
# 5. Choose a dataset from the **Dataset Dropdown**.
# 6. Adjust performance parameters (**Threads**, **Max Tokens**).
# 7. Toggle **RAG OFF** if you want to test the base model.
# 8. Click **Submit** to generate the response.
#
# > Note: The first execution will load the model into memory and may take longer. Subsequent queries will be faster unless you change model-specific parameters like threads or max tokens.nse.
#
# Enjoy interacting with your custom RAG LLM Chatbot!

# %%
def process_inputs(b):
    """
    Process inputs from the interactive chat interface.
    """
    global previous_threads, previous_max_tokens, previous_top_k, previous_dataset
    global previous_chunk_size, previous_overlap

    with output:
        output.clear_output()
        f = io.StringIO()
        with contextlib.redirect_stdout(f), contextlib.redirect_stderr(f):
            model = model_dropdown.value
            query = query_text.value
            top_k = top_k_slider.value
            chunk_size = chunk_size_input.value
            overlap = overlap_input.value
            dataset = dataset_dropdown.value
            threads = threads_slider.value
            max_tokens = max_token_input.value
            rag_off = rag_off_checkbox.value

            bot.get_model(model=model)
            bot.download_dataset(dataset=dataset)
            if (threads != previous_threads or max_tokens != previous_max_tokens or
                top_k != previous_top_k):
                print("Loading model with new parameters")
                bot.load_model(
                    n_threads=threads,
                    max_tokens=max_tokens,
                    repeat_penalty=1.50,
                    n_batch=threads,
                    top_k=top_k
                )
                previous_threads = threads
                previous_max_tokens = max_tokens
                previous_top_k = top_k

            # Rebuild vector DB if needed
            if (dataset != previous_dataset or chunk_size != previous_chunk_size or
                overlap != previous_overlap):
                print("Rebuilding vector DB")
                bot.build_vectordb(chunk_size=chunk_size, overlap=overlap)
                previous_dataset = dataset
                previous_chunk_size = chunk_size
                previous_overlap = overlap
            bot.retrieval_mechanism(
                user_input=query,
                top_k=top_k,
                context_verbosity=True,
                rag_off=rag_off
            )
            response = bot.inference()
            styled_response = f"""
            <div style="
                background-color: lightblue;
                border-radius: 15px;
                padding: 10px;
                font-family: Arial, sans-serif;
                color: black;
                max-width: 600px;
                word-wrap: break-word;
                margin: 10px;
                font-size: 14px;">
                {response}
            </div>
            """
            display(HTML(styled_response))

def create_chat_interface():
    """
    Create and display the interactive chat interface widgets.
    """
    global model_dropdown, query_text, top_k_slider, rag_off_checkbox
    global chunk_size_input, overlap_input, dataset_dropdown
    global threads_slider, max_token_input, output

    model_dropdown = widgets.Dropdown(
        options=['Falcon', 'Gemma-2-2B-IT'],
        description='Model:',
        disabled=False,
    )
    query_layout = widgets.Layout(width='400px', height='100px')
    query_text = widgets.Textarea(
        placeholder='Type your query here',
        description='Query:',
        disabled=False,
        layout=query_layout
    )
    top_k_slider = widgets.IntSlider(
        value=2,
        min=1,
        max=4,
        step=1,
        description='Top K:',
        disabled=False,
        continuous_update=False,
        orientation='horizontal',
        readout=True,
        readout_format='d'
    )
    rag_off_checkbox = widgets.Checkbox(
        value=False,
        description='RAG OFF?',
        disabled=False,
        indent=False,
        tooltip='Turn off RAG and use only the base model'
    )
    chunk_size_input = widgets.BoundedIntText(
        value=500,
        min=5,
        max=5000,
        step=1,
        description='Chunk Size:',
        disabled=False
    )
    overlap_input = widgets.BoundedIntText(
        value=50,
        min=0,
        max=1000,
        step=1,
        description='Overlap:',
        disabled=False
    )
    dataset_dropdown = widgets.Dropdown(
        options=['robot maintenance',
                 'basketball coach',
                 'physics professor',
                 'grocery cashier'],
        description='Dataset:',
        disabled=False,
    )
    threads_slider = widgets.IntSlider(
        value=8,
        min=2,
        max=200,
        step=1,
        description='Threads:',
        disabled=False,
        continuous_update=False,
        orientation='horizontal',
        readout=True,
        readout_format='d'
    )
    max_token_input = widgets.BoundedIntText(
        value=50,
        min=5,
        max=500,
        step=5,
        description='Max Tokens:',
        disabled=False
    )

    # Layout
    left_column = widgets.VBox([
        model_dropdown,
        top_k_slider,
        rag_off_checkbox,
        chunk_size_input,
        overlap_input,
        dataset_dropdown,
        threads_slider,
        max_token_input
    ])

    submit_button = widgets.Button(description="Submit")
    submit_button.on_click(process_inputs)
    right_column = widgets.VBox([query_text, submit_button])
    interface_layout = widgets.HBox([left_column, right_column])
    output = widgets.Output()
    display(interface_layout, output)

# %%
bot = RAGBot()
previous_threads = None
previous_max_tokens = None
previous_top_k = None
previous_dataset = None
previous_chunk_size = None
previous_overlap = None
previous_temp = None

# Create and display the interface
create_chat_interface()
# Out:
# HBox(children=(VBox(children=(Dropdown(description='Model:', options=('Falcon', 'Gemma-2-2B-IT'), value='Falco…
# Output()

# %% [markdown]
# ## Disclaimer for Using Large Language Models
#
# Please be aware that while Large Language Models like Falcon are powerful tools for text generation, they may sometimes produce results that are unexpected, biased, or inconsistent with the given prompt. It's advisable to carefully review the generated text and consider the context and application in which you are using these models.
#
# Usage of these models must also adhere to the licensing agreements and be in accordance with ethical guidelines and best practices for AI. If you have any concerns or encounter issues with the models, please refer to the respective model cards and documentation provided in the links above.

# %%
# Controlled RAG experiments: vary retrieval and chunking settings
# and compare outputs on a fixed question.

experiment_query = "How should I respond when a customer reports unusual vibration after replacing a servo motor?"
experiment_dataset = "robot maintenance"

bot = RAGBot()
bot.get_model(model="Falcon")
bot.download_dataset(dataset=experiment_dataset)
bot.load_model(
    n_threads=8,
    max_tokens=90,
    repeat_penalty=1.50,
    n_batch=8,
    top_k=40,
)

experiments = [
    {
        "name": "A: focused retrieval",
        "chunk_size": 300,
        "overlap": 30,
        "retrieval_top_k": 1,
        "generation_top_k": 40,
    },
    {
        "name": "B: broader retrieval",
        "chunk_size": 300,
        "overlap": 30,
        "retrieval_top_k": 4,
        "generation_top_k": 40,
    },
    {
        "name": "C: larger chunks",
        "chunk_size": 900,
        "overlap": 100,
        "retrieval_top_k": 2,
        "generation_top_k": 40,
    },
]

results = []

for cfg in experiments:
    print("\n" + "=" * 80)
    print(f"Running {cfg['name']}")
    print(
        f"chunk_size={cfg['chunk_size']}, overlap={cfg['overlap']}, "
        f"retrieval_top_k={cfg['retrieval_top_k']}"
    )

    bot.build_vectordb(chunk_size=cfg["chunk_size"], overlap=cfg["overlap"])
    bot.top_k = cfg["generation_top_k"]

    bot.retrieval_mechanism(
        user_input=experiment_query,
        top_k=cfg["retrieval_top_k"],
        context_verbosity=False,
        rag_off=False,
    )
    response = bot.inference()

    results.append({
        "name": cfg["name"],
        "config": cfg,
        "response": response,
    })

    print("Response:")
    print(response)

print("\n" + "#" * 80)
print("Qualitative comparison summary")
for item in results:
    response = item["response"].strip().replace("\n", " ")
    preview = (response[:300] + "...") if len(response) > 300 else response
    print(f"\n{item['name']}")
    print(f"Preview: {preview}")

print("\nNotes:")
print("- Lower retrieval_top_k usually yields narrower, more on-topic responses.")
print("- Higher retrieval_top_k tends to add breadth, but may introduce extra detail/noise.")
print("- Larger chunk_size often preserves longer procedures, but can dilute retrieval precision.")
# Out:
# data already exists in path.
#
# ================================================================================
# Running A: focused retrieval
# chunk_size=300, overlap=30, retrieval_top_k=1
# /tmp/ipykernel_3068/140264924.py:59: LangChainDeprecationWarning: Default values for HuggingFaceEmbeddings.model_name were deprecated in LangChain 0.2.16 and will be removed in 0.4.0. Explicitly pass a model_name to the HuggingFaceEmbeddings constructor instead.
#   embedding=HuggingFaceEmbeddings(),
# /tmp/ipykernel_3068/140264924.py:58: UserWarning: Using InMemoryVectorStore as the default vectorstore.This memory store won't persist data. You should explicitlyspecify a VectorStore when using VectorstoreIndexCreator
#   self.index = VectorstoreIndexCreator(
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Response:
# Given the context and your customer's feedback, here's how you might address the issue:
#
# "Customer: The robotic arm is experiencing excessive vibrations while operating, affecting its precision. Agent: You've mentioned that vibration issues could be due to unbalanced loads or mechanical misalignments. It sounds like we've identified potential causes. To resolve this, please follow these steps: First, verify the load distribution; ensure that all components
#
# ================================================================================
# Running B: broader retrieval
# chunk_size=300, overlap=30, retrieval_top_k=4
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Response:
# Upon receiving a report of unusual vibration after replacing a servo motor, follow these steps to address the issue:
#
# 1. Verify the Replacement: Confirm that the replacement servo motor was installed correctly, paying attention to the polarity and securing it properly. It's possible that a misalignment or incorrect installation could cause vibrations.
#
# 2. Inspect the Servo: Check the servo's mechanical components for any signs of wear or damage, such as loose connections
#
# ================================================================================
# Running C: larger chunks
# chunk_size=900, overlap=100, retrieval_top_k=2
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Response:
# "Customer: The robotic arm is experiencing excessive vibrations after replacing the servo motor. Agent: Vibration issues can be caused by unbalanced loads or mechanical misalignments. Verify that the loads are evenly distributed and inspect the arm's mechanical components. If necessary, we can provide further assistance to address the vibrations."
#
# ################################################################################
# Qualitative comparison summary
#
# A: focused retrieval
# Preview: Given the context and your customer's feedback, here's how you might address the issue:  "Customer: The robotic arm is experiencing excessive vibrations while operating, affecting its precision. Agent: You've mentioned that vibration issues could be due to unbalanced loads or mechanical misalignment...
#
# B: broader retrieval
# Preview: Upon receiving a report of unusual vibration after replacing a servo motor, follow these steps to address the issue:  1. Verify the Replacement: Confirm that the replacement servo motor was installed correctly, paying attention to the polarity and securing it properly. It's possible that a misalignm...
#
# C: larger chunks
# Preview: "Customer: The robotic arm is experiencing excessive vibrations after replacing the servo motor. Agent: Vibration issues can be caused by unbalanced loads or mechanical misalignments. Verify that the loads are evenly distributed and inspect the arm's mechanical components. If necessary, we can provi...
#
# Notes:
# - Lower retrieval_top_k usually yields narrower, more on-topic responses.
# - Higher retrieval_top_k tends to add breadth, but may introduce extra detail/noise.
# - Larger chunk_size often preserves longer procedures, but can dilute retrieval precision.
